# %%
from BloomsDetector import l1
import matplotlib.pyplot as plt
range = (0,100)
# Out:
# The paper has 81 questions that come under the category of remember.
# The paper has 3 questions that come under the category of understand.
# The paper has 19 questions that come under the category of application.
# The paper has 52 questions that come under the category of analysis.
# The paper has 115 questions that come under the category of evaluate.
# The paper has 27 questions that come under the category of creation.
#
# Paper Level =  5

# %%
print(l1)
# Out:
# [81, 3, 19, 52, 115, 27]

# %%
# x-coordinates of left sides of bars  
blooms = [1, 2, 3, 4, 5, 6] 


# heights of bars = l1
  
# labels for bars 
blooms_label = ['remembering', 'understanding', 'applying','analyzing', 'evaluating', 'creating'] 
plt.xticks(blooms, blooms_label, rotation='vertical')

# plotting a bar chart 
plt.bar(blooms, l1, tick_label = blooms_label, 
        width = 0.5, color = ['red', 'green']) 
  
# naming the x-axis 
plt.xlabel("Bloom's Taxonomy Level") 
# naming the y-axis 
plt.ylabel('No of Questions') 
# plot title 
plt.title("Bloom's Taxonomy for the Question Paper") 
# plt.title("Bloom's Taxonomy for the Paper: %s",pdf_file) 
  
# function to show the plot 
plt.show()
